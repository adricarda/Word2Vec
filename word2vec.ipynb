# %% [markdown]
# # Word embeddings

# %% [markdown]
# Skip-gram and CBOW implementation with  keras. We use  the Alice in Wonderland  book for training.

# %%
import numpy as np
np.random.seed(13)
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Embedding, Reshape, Lambda
from keras.utils import np_utils
from keras.utils.data_utils import get_file
from keras.preprocessing.text import Tokenizer
from keras.utils.vis_utils import model_to_dot
from keras.preprocessing import sequence
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors as nn
from itertools import islice
from matplotlib import pylab
from __future__ import division
from sklearn.metrics.pairwise import cosine_distances
import operator
# Out:
# Using TensorFlow backend.

# %%
path = 'alice.txt'
corpus = open(path).readlines()
#take lines with more than 1 word
corpus = [sentence for sentence in corpus if sentence.count(" ") >= 2]

#create vocabulary (first position reserved for padding)
tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'+"'")
tokenizer.fit_on_texts(corpus)
#convert text to sequence of integers according to vocabulary
corpus = tokenizer.texts_to_sequences(corpus)

#get corpus size + 1 because of padding
V = len(tokenizer.word_index) + 1

dims = [50,150,300]
window_size = 2

# %% [markdown]
# # Skipgram

# %%
#prepare data for skipgram
def generate_data_skipgram(corpus, window_size, V):
  trainPairs = []
  # iterate over all sentences to build the training pairs
  for sentence in corpus:
    # let every word from the sentence be the center word
    for center_word_pos in range(len(sentence)):
        # get the index of the word within the entire corpus, not only sentence
        center_word_idx = sentence[center_word_pos]
        # take the words within the window size as context
        for w in range(-window_size, window_size + 1):
            # position of the content word
            context_word_pos = center_word_pos + w
            # make soure not jump outside of a sentence
            if context_word_pos < 0 or context_word_pos >= len(sentence) or center_word_pos == context_word_pos:
                continue
            # get the index of the word within the entire corpus, not only sentence
            context_word_idx = sentence[context_word_pos]
            # add word and context to the training pairs
            trainPairs.append((center_word_idx, context_word_idx))

  # initialize empty lists
  x=[]
  y=[]
  all_outY = []
  # iterate over all training pairs
  for pair in trainPairs:
    # for the one hot encoding
    all_outY = np_utils.to_categorical(pair[1],V)
    # append the word and the one hot encoding
    x.append(pair[0])
    y.append(all_outY)
    
  # return the word and the matrix with shape (number of train pairs * vocab size)
  return np.array(x) , np.array(y).reshape(-1, V)

# %%
#training data
x,y = generate_data_skipgram(corpus,window_size,V)

# %%
#create Skipgram model

skipgramsModels = []
for dim in dims:
  print("Skipgram model with dimensions:",dim)
  skipgram = Sequential()
  #if you use embedding (instead of dense layer) input doesn't have to be one hot encoded
  skipgram.add(Embedding(V, dim, input_length=1, embeddings_initializer='glorot_uniform')) 
  # respape the output of the embedding layer
  skipgram.add(Reshape((dim, )))
  skipgram.add(Dense(V, activation='softmax', kernel_initializer='uniform'))

  # compile the model
  skipgram.compile(loss='categorical_crossentropy', optimizer='adadelta')
  skipgram.summary()
  skipgramsModels.append(skipgram)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0716 07:46:33.683457 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0716 07:46:33.749584 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0716 07:46:33.761143 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0716 07:46:33.800882 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0716 07:46:33.827227 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# Skipgram model with dimensions: 50
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1, 50)             128350
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2567)              130917
# =================================================================
# Total params: 259,267
# Trainable params: 259,267
# Non-trainable params: 0
# _________________________________________________________________
# Skipgram model with dimensions: 150
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 1, 150)            385050
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2567)              387617
# =================================================================
# Total params: 772,667
# Trainable params: 772,667
# Non-trainable params: 0
# _________________________________________________________________
# Skipgram model with dimensions: 300
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 1, 300)            770100
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2567)              772667
# =================================================================
# Total params: 1,542,767
# Trainable params: 1,542,767
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train Skipgram model
model = 0
for skipgram in skipgramsModels:
  print("Training Skipgram model with",dims[model], "dimensions")
  skipgram.fit(x, y, batch_size=128, epochs=15, verbose=1)
  model+=1
# Out:
# W0716 07:47:09.993454 139987615254400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training Skipgram model with 50 dimensions
# W0716 07:47:10.103683 139987615254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/15
# 93182/93182 [==============================] - 8s 86us/step - loss: 7.5152
# Epoch 2/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 6.6871
# Epoch 3/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 6.2837
# Epoch 4/15
# 93182/93182 [==============================] - 4s 44us/step - loss: 6.1054
# Epoch 5/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 6.0001
# Epoch 6/15
# 93182/93182 [==============================] - 4s 44us/step - loss: 5.9280
# Epoch 7/15
# 93182/93182 [==============================] - 4s 44us/step - loss: 5.8755
# Epoch 8/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.8342
# Epoch 9/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.8008
# Epoch 10/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.7720
# Epoch 11/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.7469
# Epoch 12/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.7243
# Epoch 13/15
# 93182/93182 [==============================] - 4s 46us/step - loss: 5.7036
# Epoch 14/15
# 93182/93182 [==============================] - 4s 44us/step - loss: 5.6852
# Epoch 15/15
# 93182/93182 [==============================] - 4s 45us/step - loss: 5.6682
# Training Skipgram model with 150 dimensions
# Epoch 1/15
# 93182/93182 [==============================] - 5s 56us/step - loss: 7.4339
# Epoch 2/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 6.5351
# Epoch 3/15
# 93182/93182 [==============================] - 5s 53us/step - loss: 6.1726
# Epoch 4/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 6.0072
# Epoch 5/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.9070
# Epoch 6/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.8373
# Epoch 7/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.7843
# Epoch 8/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.7409
# Epoch 9/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.7055
# Epoch 10/15
# 93182/93182 [==============================] - 5s 55us/step - loss: 5.6748
# Epoch 11/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.6473
# Epoch 12/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.6220
# Epoch 13/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.5986
# Epoch 14/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.5764
# Epoch 15/15
# 93182/93182 [==============================] - 5s 54us/step - loss: 5.5550
# Training Skipgram model with 300 dimensions
# Epoch 1/15
# 93182/93182 [==============================] - 6s 65us/step - loss: 7.3823
# Epoch 2/15
# 93182/93182 [==============================] - 6s 62us/step - loss: 6.4542
# Epoch 3/15
# 93182/93182 [==============================] - 6s 62us/step - loss: 6.1114
# Epoch 4/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.9527
# Epoch 5/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.8539
# Epoch 6/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.7831
# Epoch 7/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.7290
# Epoch 8/15
# 93182/93182 [==============================] - 6s 62us/step - loss: 5.6848
# Epoch 9/15
# 93182/93182 [==============================] - 6s 62us/step - loss: 5.6468
# Epoch 10/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.6126
# Epoch 11/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.5817
# Epoch 12/15
# 93182/93182 [==============================] - 6s 62us/step - loss: 5.5525
# Epoch 13/15
# 93182/93182 [==============================] - 6s 61us/step - loss: 5.5255
# Epoch 14/15
# 93182/93182 [==============================] - 6s 63us/step - loss: 5.4994
# Epoch 15/15
# 93182/93182 [==============================] - 6s 63us/step - loss: 5.4745

# %%
# using the word2vec model make two tables
# one to map from words to index and the other one from index to word
word2idx = tokenizer.word_index
idx2word = {v: k for k, v in word2idx.items()}

#analogy function implementation
model = 0
for skipgram in skipgramsModels:
  print("Skipgram model with dimensions:",dims[model])
  #get embeddings matrix
  weights = skipgram.get_weights()[0]
  print(weights.shape)
  
  idx2emb = {}
  for word in word2idx.keys():
    wid = word2idx[word]
    idx2emb[wid] = np.array(weights[wid]).reshape(1,-1)
    

  def embed2Words(word1,word2):
    """function to calculate the cosine distance of two words"""
    # look the index of the word up
    wid1 = word2idx[word1]
    wid2 = word2idx[word2]
    # extract the embedding for the word
    source_emb = idx2emb[wid1]
    target_emb = idx2emb[wid2]
    # calculate the distance
    distance = cosine_distances(source_emb,target_emb)  
    return distance.item()

  # see similarities between queen and king
  # queen = embed('king')-embed('man')+embed('woman')
  # 0 = embed('king')-embed('man')+embed('woman')-embed('queen')
  val1 = embed2Words('king','man')
  val2 = embed2Words('woman','queen')
  print("Analogy function:")
  print("Queen = king - man + woman")
  print("Is the same as:")
  print("0 = king - man + woman - queen")
  print("The expected value is 0")
  print("Obteined value using skipgram with", dims[model],"dimensions:",val1+val2)

  # just an example: woman and man should be not so far
  print("Just an example: woman and man should be not so far")
  print("Distance:",embed2Words('woman','man'))
  def similar_words(word):
    """function that given a certain word returns us the 10 most similar words"""
    # find the index of the word
    wid = word2idx[word]
    # get its embedding
    source_emb = idx2emb[wid]
    distances = []
    # iterate over all other words in the vocabulary
    for i in range(1, V):
        # if we are at the word itself: skip
        if i == wid:
            continue
        # get the embedding for the target word
        target_emb = idx2emb[i]
        # calculate the distance between the two words
        distances.append(((wid, i), cosine_distances(source_emb, target_emb)))
    # sort the list of distances and keep the 10 first
    sorted_distances = sorted(distances, key=operator.itemgetter(1))[0:10]
    predictions = [idx2word[x[0][1]] for x in sorted_distances]
    
    # format the output
    print("{:s} => {:s}".format(word, ", ".join(predictions)))
    return predictions
    
  predictions1 = similar_words("queen")
  predictions2 = similar_words("king")
  predictions3 = similar_words("rabbit")
  model +=1
  print("\n")
# Out:
# Skipgram model with dimensions: 50
# (2567, 50)
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using skipgram with 50 dimensions: 1.1065442562103271
# Just an example: woman and man should be not so far
# Distance: 0.2970593571662903
# queen => dormouse, king, gryphon, duchess, footman, hatter, first, caterpillar, march, other
# king => gryphon, duchess, hatter, dormouse, caterpillar, queen, dodo, cat, march, footman
# rabbit => white, queen, kid, by, dormouse, while, duchess, door, first, whole
#
#
# Skipgram model with dimensions: 150
# (2567, 150)
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using skipgram with 150 dimensions: 1.2361584305763245
# Just an example: woman and man should be not so far
# Distance: 0.5223388671875
# queen => dormouse, duchess, king, footman, cook, gryphon, first, caterpillar, hatter, executioner
# king => gryphon, duchess, dormouse, caterpillar, dodo, hatter, queen, footman, cat, pigeon
# rabbit => kid, duchess, queen, footman, dormouse, king, first, read, door, hatter
#
#
# Skipgram model with dimensions: 300
# (2567, 300)
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using skipgram with 300 dimensions: 1.2726451754570007
# Just an example: woman and man should be not so far
# Distance: 0.6136317253112793
# queen => king, dormouse, duchess, cook, caterpillar, first, gryphon, footman, hatter, the
# king => caterpillar, duchess, gryphon, hatter, dormouse, queen, dodo, lory, footman, cat
# rabbit => kid, gloves, queen, hatter, dormouse, read, duchess, bill, gryphon, king

# %%
import matplotlib.pyplot as plt

#Visualization results trained word embeddings
from sklearn.manifold import TSNE

predictions = predictions1 + predictions2 + predictions3
#remove duplicated words from the predictions list
predictions = set(predictions)

#put all the previous similar word into the same list
words_ids = [word2idx[w] for w in predictions]

word_vectors = np.array([weights[idx] for idx in words_ids])
print('Total words:', len(predictions), '\tWord Embedding shapes:', word_vectors.shape)

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=3)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(word_vectors)
print(T.shape)
labels = predictions

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='steelblue', edgecolors='k')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-1, -12), textcoords='offset points')
# Out:
# Total words: 18 	Word Embedding shapes: (18, 300)
# (18, 2)

# %% [markdown]
# As we can see from the plot there some clusters (e.g. queen, duchess and king are close). The same holds for animals (e.g. dormhouse, caterpillar, cat and gryphon)

# %% [markdown]
# # CBOW

# %%
#prepare data for CBOW

def generate_data_CBOW(corpus, window_size, vocab_size):
  # the context are the words to the left and right (which is double the window size)
  context_length = window_size*2
  x = []
  y = []
  # iterate over all sentences
  for sentence in corpus:
      sentence_length = len(sentence)
      for i, global_index in enumerate(sentence):
        # set the boundaries for the context
          context_words = []
          label_word   = []            
          start = i - window_size
          end = i + window_size + 1
          # extract the context words within the boundaries
          context_words = [[sentence[j] for j in range(start, end) 
                                              if 0 <= j < sentence_length and j != i]]
          # assign the label word its global index from the entire corpus
          label_word = global_index
          # add training pairs of padded context words ...
          x.append(sequence.pad_sequences(context_words, maxlen=context_length))
          # ... and a one hot representation of the word
          y.append(np_utils.to_categorical(label_word, vocab_size))
  return (np.array(x).reshape(-1, context_length), np.array(y))

# %%
#get x and y's for training data
x,y = generate_data_CBOW(corpus,window_size,V)

# %%
#create CBOW model
cbowsModels = []
for dim in dims:
  print("CBOW model with dimensions:",dim)
  cbow = Sequential()
  # we use an embedding layer: input size is defined by the size of vocabulary
  # output size is equal to dim
  cbow.add(Embedding(input_dim=V, output_dim=dim, input_length=window_size*2))
  # now in the second layer, we sum up everything like in the paper
  cbow.add(Lambda(lambda x: K.sum(x, axis=1), output_shape=(dim,)))
  cbow.add(Dense(V, activation='softmax'))

  #compile the model
  cbow.compile(loss='categorical_crossentropy', optimizer='adadelta')

  cbow.summary()
  cbowsModels.append(cbow)
# Out:
# CBOW model with dimensions: 50
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 4, 50)             128350
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2567)              130917
# =================================================================
# Total params: 259,267
# Trainable params: 259,267
# Non-trainable params: 0
# _________________________________________________________________
# CBOW model with dimensions: 150
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 4, 150)            385050
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 150)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2567)              387617
# =================================================================
# Total params: 772,667
# Trainable params: 772,667
# Non-trainable params: 0
# _________________________________________________________________
# CBOW model with dimensions: 300
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 4, 300)            770100
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 300)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2567)              772667
# =================================================================
# Total params: 1,542,767
# Trainable params: 1,542,767
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model
model=0
for cbow in cbowsModels:
  print("Training CBOW model with",dims[model], "dimensions")
  cbow.fit(x, y, batch_size=128, epochs=15, verbose=1)
  model+=1
# Out:
# Training CBOW model with 50 dimensions
# Epoch 1/15
# 27179/27179 [==============================] - 2s 56us/step - loss: 7.3565
# Epoch 2/15
# 27179/27179 [==============================] - 1s 46us/step - loss: 6.4477
# Epoch 3/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 6.1554
# Epoch 4/15
# 27179/27179 [==============================] - 1s 48us/step - loss: 5.9960
# Epoch 5/15
# 27179/27179 [==============================] - 1s 50us/step - loss: 5.8775
# Epoch 6/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 5.7769
# Epoch 7/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 5.6869
# Epoch 8/15
# 27179/27179 [==============================] - 1s 50us/step - loss: 5.6050
# Epoch 9/15
# 27179/27179 [==============================] - 1s 48us/step - loss: 5.5300
# Epoch 10/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 5.4610
# Epoch 11/15
# 27179/27179 [==============================] - 1s 51us/step - loss: 5.3957
# Epoch 12/15
# 27179/27179 [==============================] - 1s 50us/step - loss: 5.3358
# Epoch 13/15
# 27179/27179 [==============================] - 1s 48us/step - loss: 5.2786
# Epoch 14/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 5.2255
# Epoch 15/15
# 27179/27179 [==============================] - 1s 49us/step - loss: 5.1744
# Training CBOW model with 150 dimensions
# Epoch 1/15
# 27179/27179 [==============================] - 2s 73us/step - loss: 7.2327
# Epoch 2/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 6.2954
# Epoch 3/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.9889
# Epoch 4/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.7936
# Epoch 5/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.6452
# Epoch 6/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.5222
# Epoch 7/15
# 27179/27179 [==============================] - 2s 61us/step - loss: 5.4153
# Epoch 8/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.3195
# Epoch 9/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.2309
# Epoch 10/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.1489
# Epoch 11/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 5.0752
# Epoch 12/15
# 27179/27179 [==============================] - 2s 61us/step - loss: 5.0051
# Epoch 13/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 4.9395
# Epoch 14/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 4.8768
# Epoch 15/15
# 27179/27179 [==============================] - 2s 60us/step - loss: 4.8168
# Training CBOW model with 300 dimensions
# Epoch 1/15
# 27179/27179 [==============================] - 2s 85us/step - loss: 7.0991
# Epoch 2/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 6.1824
# Epoch 3/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 5.8619
# Epoch 4/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 5.6497
# Epoch 5/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 5.4871
# Epoch 6/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 5.3510
# Epoch 7/15
# 27179/27179 [==============================] - 2s 70us/step - loss: 5.2304
# Epoch 8/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 5.1242
# Epoch 9/15
# 27179/27179 [==============================] - 2s 72us/step - loss: 5.0267
# Epoch 10/15
# 27179/27179 [==============================] - 2s 70us/step - loss: 4.9378
# Epoch 11/15
# 27179/27179 [==============================] - 2s 70us/step - loss: 4.8540
# Epoch 12/15
# 27179/27179 [==============================] - 2s 70us/step - loss: 4.7745
# Epoch 13/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 4.6995
# Epoch 14/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 4.6267
# Epoch 15/15
# 27179/27179 [==============================] - 2s 71us/step - loss: 4.5581

# %%
# using the word2vec model make two tables
# one to map from words to index and the other one from index to word
word2idx = tokenizer.word_index
idx2word = {v: k for k, v in word2idx.items()}

#Implement your own analogy function
model = 0
for cbow in cbowsModels:
  print("cbow model with dimensions:",dims[model])
  weights = cbow.get_weights()[0]
  
  idx2emb = {}
  for word in word2idx.keys():
    wid = word2idx[word]
    idx2emb[wid] = np.array(weights[wid]).reshape(1,-1)

  def embed2Words(word1,word2):
    """function to calculate the cosine distance of two words"""
    # look the index of the word up
    wid1 = word2idx[word1]
    wid2 = word2idx[word2]
    # extract the embedding for the word
    source_emb = idx2emb[wid1]
    target_emb = idx2emb[wid2]
    # calculate the distance
    distance = cosine_distances(source_emb,target_emb)  
    return distance.item()

  # see similarities between queen and king
  # queen = embed('king')-embed('man')+embed('woman')
  # 0 = embed('king')-embed('man')+embed('woman')-embed('queen')
  val1 = embed2Words('king','man')
  val2 = embed2Words('woman','queen')
  print("Analogy function:")
  print("Queen = king - man + woman")
  print("Is the same as:")
  print("0 = king - man + woman - queen")
  print("The expected value is 0")
  print("Obteined value using cbow with", dims[model],"dimensions:",val1+val2)

  # just an example: woman and man should be not so far
  print("Just an example: woman and man should be not so far")
  print("Distance:",embed2Words('woman','man'))
  def similar_words(word):
    """function that given a certain word returns us the 10 most similar words"""
    # find the index of the word
    wid = word2idx[word]
    # get its embedding
    source_emb = idx2emb[wid]
    distances = []
    # iterate over all other words in the vocabulary
    for i in range(1, V):
        # if we are at the word itself: skip
        if i == wid:
            continue
        # get the embedding for the target word
        target_emb = idx2emb[i]
        # calculate the distance between the two words
        distances.append(((wid, i), cosine_distances(source_emb, target_emb)))
    # sort the list of distances and keep the 10 first
    sorted_distances = sorted(distances, key=operator.itemgetter(1))[0:10]
    predictions = [idx2word[x[0][1]] for x in sorted_distances]
    
    # format the output
    print("{:s} => {:s}".format(word, ", ".join(predictions)))
    return predictions
    
  predictions1 = similar_words("queen")
  predictions2 = similar_words("king")
  predictions3 = similar_words("rabbit")
  model +=1
  print("\n")
# Out:
# cbow model with dimensions: 50
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using cbow with 50 dimensions: 1.337368667125702
# Just an example: woman and man should be not so far
# Distance: 0.7060388326644897
# queen => dormouse, caterpillar, duchess, gryphon, footman, witness, others, king, words, roof
# king => caterpillar, duchess, hatter, gryphon, dormouse, cat, youth, queen, dodo, footman
# rabbit => dormouse, witness, footman, queen, caterpillar, cook, dodo, trial, duchess, jurors
#
#
# cbow model with dimensions: 150
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using cbow with 150 dimensions: 1.5748576521873474
# Just an example: woman and man should be not so far
# Distance: 0.5624476671218872
# queen => dormouse, caterpillar, footman, duchess, king, dodo, cook, lory, youth, hatter
# king => caterpillar, duchess, hatter, cat, dormouse, gryphon, dodo, lory, footman, youth
# rabbit => footman, queen, argument, duchess, dormouse, verses, cook, game, pigeon, hedgehog
#
#
# cbow model with dimensions: 300
# Analogy function:
# Queen = king - man + woman
# Is the same as:
# 0 = king - man + woman - queen
# The expected value is 0
# Obteined value using cbow with 300 dimensions: 1.565084993839264
# Just an example: woman and man should be not so far
# Distance: 0.7647196054458618
# queen => dormouse, caterpillar, footman, duchess, king, cat, cook, hatter, youth, gryphon
# king => caterpillar, dodo, gryphon, duchess, dormouse, hatter, youth, cat, lory, pigeon
# rabbit => kid, gloves, verses, queen, master, lizard, read, duchess, lory, puppy

# %%
import matplotlib.pyplot as plt

#Visualization results trained word embeddings
from sklearn.manifold import TSNE

predictions = predictions1 + predictions2 + predictions3
#remove duplicated words from the predictions list
predictions = set(predictions)

#put all the previous similar word into the same list
words_ids = [word2idx[w] for w in predictions]

word_vectors = np.array([weights[idx] for idx in words_ids])
print('Total words:', len(predictions), '\tWord Embedding shapes:', word_vectors.shape)

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=3)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(word_vectors)
print(T.shape)
labels = predictions

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='steelblue', edgecolors='k')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-1, -12), textcoords='offset points')
# Out:
# Total words: 21 	Word Embedding shapes: (21, 300)
# (21, 2)

# %% [markdown]
# ### Discussion of the advantages of CBOW and Skipgram, the advantages of negative sampling and drawbacks of CBOW and Skipgram

# %% [markdown]
# #### Advantages against other models
#
# According to the paper, their accuracy in semantics and syntax is outperforming the one of RNNLM and NNLM. This suggests that they are producing reasonable results without being too complex as models. Like stated in the paper: “because of much lower computational complexity, it is possible to compute very accurate high dimensional word vectors from a much larger data set”.
#
# A disadvantage of the models is the softmax function at the last layer. This slows down the process due to computational complexity. For this reason, negative sampling has been introduced. With negative sampling, each training sample only modifies a small percentage of the weights in the network instead of all of them. The idea is to turn the problem into a binary classification problem in which we predict 1 (in the case of skipgram) if the context and target word appear together and 0 if this is not the case. Doing this way, we do not need to compute the final softmax.
#
# #### Advantages and Disadvantages between each other
# What are the main advantages of CBOW and Skipgram?
# What are the main drawbacks of CBOW and Skipgram?
#
# 1)On semantic level, the advantage of Skipgram is that it produces a much higher accuracy (according to the paper, page 8, table 5). In syntax this does not hold necessarily.
#
# 2)According to Mikolov, Skipgram works well with small amount of data and is found to represent rare words well. This is their advantage towards CBOW. A possible explanation why this is the cause would be that in CBOW the vectors from the context words are averaged (or summed up in our case) before predicting the center word. In Skipgram there is no averaging of embedding vectors. It seems like the model can learn better representations for the rare words when their vectors are not averaged with the other context words in the process of making the predictions. (https://stats.stackexchange.com/questions/180548/why-is-skip-gram-better-for-infrequent-words-than-cbow)
#
# 3)On the other hand, CBOW is faster and has better representations for more frequent words. This is due to the fact that by predicting from the context to one word only like in CBOW, we have less training data. Even if it has a higher dimensionality, the amount dominates the time consumption. (https://towardsdatascience.com/introduction-to-word-embedding-and-word2vec-652d0c2060fa)
#
# 4)For Skipgram, you can create a lot more training instances from limited amount of data than in CBOW because you are taking pairs of the center word with every word in the context. More data usually makes learning work better.
#
# 5)The CBOW model does not take into account the order of the words that stand in the context before or after it. Also when Skipgram is used to predict the words in its context, their order does not play a role. You can also see this property as an advantage because it makes the model more simple.
